# %%
import pandas as pd
import seaborn as sns

# %%
avy_df = pd.read_csv('./data/avy_rating.csv')
avy_df = avy_df.set_index('date')
wet_df = pd.read_csv('./data/avg_weather_data.csv')
wet_df = wet_df.set_index('Date')

# %% [markdown]
# Find all instances of updated reports due to bad forcasts
# This could be useful in testing later..

# %%
avy_df[avy_df.index.duplicated(keep=False)]
# Out:
#                   rating                                             report  \
# date
# 2019-02-25          high  https://www.sierraavalanchecenter.org/advisory...
# 2019-02-25      moderate  https://www.sierraavalanchecenter.org/advisory...
# 2019-02-09          high  https://www.sierraavalanchecenter.org/advisory...
# 2019-02-09  considerable  https://www.sierraavalanchecenter.org/advisory...
# 2018-03-04  considerable  https://www.sierraavalanchecenter.org/advisory...
# 2018-03-04      moderate  https://www.sierraavalanchecenter.org/advisory...
# 2012-03-14  considerable  https://www.sierraavalanchecenter.org/content/...
# 2012-03-14  considerable  https://www.sierraavalanchecenter.org/content/...
# 2012-02-16      moderate  https://www.sierraavalanchecenter.org/content/...
# 2012-02-16      moderate  https://www.sierraavalanchecenter.org/content/...
# 2012-01-29           low  https://www.sierraavalanchecenter.org/content/...
# 2012-01-29           low  https://www.sierraavalanchecenter.org/content/...
# 2012-01-29           low  https://www.sierraavalanchecenter.org/content/...
# 2010-12-28      moderate  https://www.sierraavalanchecenter.org/content/...
# 2010-12-28      moderate  https://www.sierraavalanchecenter.org/content/...
# 2010-11-23  considerable  https://www.sierraavalanchecenter.org/content/...
# 2010-11-23  considerable  https://www.sierraavalanchecenter.org/content/...
# 2009-12-23      moderate  https://www.sierraavalanchecenter.org/content/...
# 2009-12-23      moderate  https://www.sierraavalanchecenter.org/content/...
#
#                                            problems
# date
# 2019-02-25              ['Wind Slab', 'Storm Slab']
# 2019-02-25                            ['Wind Slab']
# 2019-02-09              ['Wind Slab', 'Storm Slab']
# 2019-02-09              ['Wind Slab', 'Storm Slab']
# 2018-03-04  ['Deep Slab', 'Wind Slab', 'Loose Wet']
# 2018-03-04  ['Wind Slab', 'Deep Slab', 'Loose Wet']
# 2012-03-14                                       []
# 2012-03-14                                       []
# 2012-02-16                                       []
# 2012-02-16                                       []
# 2012-01-29                                       []
# 2012-01-29                                       []
# 2012-01-29                                       []
# 2010-12-28                                       []
# 2010-12-28                                       []
# 2010-11-23                                       []
# 2010-11-23                                       []
# 2009-12-23                                       []
# 2009-12-23                                       []

# %%
updated_rating = avy_df[avy_df.index.duplicated(keep=False)][:5]

# %%
# updated_rating.to_csv('./data/updated_ratings.csv')

# %% [markdown]
# Remove all duplicates and save data

# %%
clean_avy_df = avy_df[~avy_df.index.duplicated(keep='last')]

# %%
all(~clean_avy_df.index.duplicated(keep=False))
# Out:
# True

# %%
df = pd.merge(wet_df, clean_avy_df, left_index=True, right_index=True)
df.index.rename('date', inplace=True)

# %%
# df.to_csv('./data/data.csv')

# %%
df.drop(['report', 'problems'], axis=1, inplace=True)
df.head()
# Out:
#             Snow Depth (cm) Start of Day Values  Precipitation Increment (mm)  \
# date
# 2008-12-17                            50.000000                      1.066667
# 2008-12-18                            43.733333                      5.466667
# 2008-12-19                            41.533333                      9.200000
# 2008-12-20                            44.200000                      3.733333
# 2008-12-21                            40.866667                     14.266667
#
#             Air Temperature Average (degC)  Wind Direction Average (degree)  \
# date
# 2008-12-17                      -11.533333                       180.000000
# 2008-12-18                       -7.420000                       236.666667
# 2008-12-19                       -5.860000                       246.666667
# 2008-12-20                       -2.813333                       192.000000
# 2008-12-21                       -0.206667                       232.666667
#
#             Wind Speed Average (km/hr)        rating
# date
# 2008-12-17                    2.800000           low
# 2008-12-18                   11.900000           low
# 2008-12-19                   15.966667  considerable
# 2008-12-20                    6.400000           low
# 2008-12-21                    8.266667           low

# %%
df.rating.value_counts()
# Out:
# moderate        925
# low             537
# considerable    256
# high             60
# na               56
# extream           2
# Name: rating, dtype: int64

# %%
low_df = df[df.rating == 'low']
mod_df = df[df.rating == 'moderate']
con_df = df[df.rating == 'considerable']
hig_df = df[df.rating == 'high']
ext_df = df[df.rating == 'extreame']

# %%
date = low_df.sample().index

# %%
df_ = df.drop('rating', axis=1)
sns.pairplot(df_.reset_index())

# %%
values = [0, 1, 2, 3, 4, 5]
conditions = (
    df['rating'] == 'na',
    df['rating'] == 'low',
    df['rating'] == 'moderate',
    df['rating'] == 'considerable',
    df['rating'] == 'high',
    df['rating'] == 'extream',
)
df['num_rating'] = np.select(conditions, values)

# %%
df_ = df.drop('rating', axis=1)
sns.pairplot(df_)

# %%
len(df.index)
# Out:
# 1836

# %%
len(set(df.index))
# Out:
# 1836
